# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pylab as plt
import seaborn as sns

from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,OneHotEncoder,OrdinalEncoder,PowerTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.impute import SimpleImputer, KNNImputer, MissingIndicator


from sklearn import set_config

set_config(transform_output="pandas")
plt.style.use('fivethirtyeight')

# %%
swiggy=pd.read_csv("swiggy_cleaned.csv")

# %%
swiggy.sample(3)
# Out:
#                rider_id   age  ratings  restaurant_latitude  \
# 1888     MYSRES05DEL01    NaN      NaN            12.323978
# 22871  COIMBRES11DEL02   21.0      4.7            11.001753
# 15552   CHENRES16DEL02   24.0      4.6            13.049645
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 1888              76.627961          12.333978           76.637961
# 22871             76.986241          11.081753           77.066241
# 15552             80.242268          13.069645           80.262268
#
#        order_date weather traffic  ...  time_taken city_name order_day  \
# 1888   2022-03-17  cloudy     low  ...          15       MYS        17
# 22871  2022-04-06   windy  medium  ...          15     COIMB         6
# 15552  2022-03-26  cloudy    high  ...          21      CHEN        26
#
#        order_month order_day_of_week is_weekend  pickup_time_minutes  \
# 1888             3          thursday          0                  NaN
# 22871            4         wednesday          0                  5.0
# 15552            3          saturday          1                 15.0
#
#       order_time_hour  order_time_of_day   distance
# 1888              NaN     after_midnight   1.554506
# 22871            17.0            evening  12.464369
# 15552            12.0          afternoon   3.104661
#
# [3 rows x 26 columns]

# %%
swiggy['distance'].describe()
# Out:
# count    41872.000000
# mean         9.719296
# std          5.602890
# min          1.465067
# 25%          4.657655
# 50%          9.193014
# 75%         13.680920
# max         20.969489
# Name: distance, dtype: float64

# %%
def bin_distance(df:pd.DataFrame,num_col):
    distance_labels=['short','medium','long','very long']
    distance_bins=[1,6,12,18,24]
    df['distance_bins']=pd.cut(df[num_col],bins=distance_bins,labels=distance_labels,right=False)
    return df

# %%
bin_distance(swiggy,'distance')
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 0        INDORES13DEL02   37.0      4.9            22.745049
# 1        BANGRES18DEL02   34.0      4.5            12.913041
# 2        BANGRES19DEL01   23.0      4.4            12.914264
# 3       COIMBRES13DEL02   38.0      4.7            11.003669
# 4        CHENRES12DEL01   32.0      4.6            12.972793
# ...                  ...   ...      ...                  ...
# 45497     JAPRES04DEL01   30.0      4.8            26.902328
# 45498     AGRRES16DEL01   21.0      4.6                  NaN
# 45499    CHENRES08DEL03   30.0      4.9            13.022394
# 45500   COIMBRES11DEL01   20.0      4.7            11.001753
# 45501  RANCHIRES09DEL02   23.0      4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 0                 75.892471          22.765049           75.912471
# 1                 77.683237          13.043041           77.813237
# 2                 77.678400          12.924264           77.688400
# 3                 76.976494          11.053669           77.026494
# 4                 80.249982          13.012793           80.289982
# ...                     ...                ...                 ...
# 45497             75.794257          26.912328           75.804257
# 45498                   NaN                NaN                 NaN
# 45499             80.242439          13.052394           80.272439
# 45500             76.986241          11.041753           77.026241
# 45501             85.325731          23.431058           85.405731
#
#        order_date     weather traffic  ...  city_name order_day order_month  \
# 0      2022-03-19       sunny    high  ...       INDO        19           3
# 1      2022-03-25      stormy     jam  ...       BANG        25           3
# 2      2022-03-19  sandstorms     low  ...       BANG        19           3
# 3      2022-04-05       sunny  medium  ...      COIMB         5           4
# 4      2022-03-26      cloudy    high  ...       CHEN        26           3
# ...           ...         ...     ...  ...        ...       ...         ...
# 45497  2022-03-24       windy    high  ...        JAP        24           3
# 45498  2022-02-16       windy     jam  ...        AGR        16           2
# 45499  2022-03-11      cloudy     low  ...       CHEN        11           3
# 45500  2022-03-07      cloudy    high  ...      COIMB         7           3
# 45501  2022-03-02         fog  medium  ...     RANCHI         2           3
#
#        order_day_of_week is_weekend pickup_time_minutes  order_time_hour  \
# 0               saturday          1                15.0             11.0
# 1                 friday          0                 5.0             19.0
# 2               saturday          1                15.0              8.0
# 3                tuesday          0                10.0             18.0
# 4               saturday          1                15.0             13.0
# ...                  ...        ...                 ...              ...
# 45497           thursday          0                10.0             11.0
# 45498          wednesday          0                15.0             19.0
# 45499             friday          0                15.0             23.0
# 45500             monday          0                 5.0             13.0
# 45501          wednesday          0                 5.0             17.0
#
#       order_time_of_day   distance  distance_bins
# 0               morning   3.025149          short
# 1               evening  20.183530      very long
# 2               morning   1.552758          short
# 3               evening   7.790401         medium
# 4             afternoon   6.210138         medium
# ...                 ...        ...            ...
# 45497           morning   1.489846          short
# 45498           evening        NaN            NaN
# 45499             night   4.657195          short
# 45500         afternoon   6.232393         medium
# 45501           evening  12.074396           long
#
# [45502 rows x 27 columns]

# %%
swiggy['order_time_hour'].describe()
# Out:
# count    43862.000000
# mean        17.423966
# std          4.817856
# min          0.000000
# 25%         15.000000
# 50%         19.000000
# 75%         21.000000
# max         23.000000
# Name: order_time_hour, dtype: float64

# %%
def bin_time(df:pd.DataFrame,num_col):
    time_labels=['after_midnight','morning','afternoon','evening','night']
    time_bins=[0,6,12,17,20,24]
    df['order_time_bins']=pd.cut(df[num_col],bins=time_bins,labels=time_labels,right=False)
    return df

# %%
bin_time(swiggy,'order_time_hour')
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 0        INDORES13DEL02   37.0      4.9            22.745049
# 1        BANGRES18DEL02   34.0      4.5            12.913041
# 2        BANGRES19DEL01   23.0      4.4            12.914264
# 3       COIMBRES13DEL02   38.0      4.7            11.003669
# 4        CHENRES12DEL01   32.0      4.6            12.972793
# ...                  ...   ...      ...                  ...
# 45497     JAPRES04DEL01   30.0      4.8            26.902328
# 45498     AGRRES16DEL01   21.0      4.6                  NaN
# 45499    CHENRES08DEL03   30.0      4.9            13.022394
# 45500   COIMBRES11DEL01   20.0      4.7            11.001753
# 45501  RANCHIRES09DEL02   23.0      4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 0                 75.892471          22.765049           75.912471
# 1                 77.683237          13.043041           77.813237
# 2                 77.678400          12.924264           77.688400
# 3                 76.976494          11.053669           77.026494
# 4                 80.249982          13.012793           80.289982
# ...                     ...                ...                 ...
# 45497             75.794257          26.912328           75.804257
# 45498                   NaN                NaN                 NaN
# 45499             80.242439          13.052394           80.272439
# 45500             76.986241          11.041753           77.026241
# 45501             85.325731          23.431058           85.405731
#
#        order_date     weather traffic  ...  order_day order_month  \
# 0      2022-03-19       sunny    high  ...         19           3
# 1      2022-03-25      stormy     jam  ...         25           3
# 2      2022-03-19  sandstorms     low  ...         19           3
# 3      2022-04-05       sunny  medium  ...          5           4
# 4      2022-03-26      cloudy    high  ...         26           3
# ...           ...         ...     ...  ...        ...         ...
# 45497  2022-03-24       windy    high  ...         24           3
# 45498  2022-02-16       windy     jam  ...         16           2
# 45499  2022-03-11      cloudy     low  ...         11           3
# 45500  2022-03-07      cloudy    high  ...          7           3
# 45501  2022-03-02         fog  medium  ...          2           3
#
#       order_day_of_week  is_weekend pickup_time_minutes order_time_hour  \
# 0              saturday           1                15.0            11.0
# 1                friday           0                 5.0            19.0
# 2              saturday           1                15.0             8.0
# 3               tuesday           0                10.0            18.0
# 4              saturday           1                15.0            13.0
# ...                 ...         ...                 ...             ...
# 45497          thursday           0                10.0            11.0
# 45498         wednesday           0                15.0            19.0
# 45499            friday           0                15.0            23.0
# 45500            monday           0                 5.0            13.0
# 45501         wednesday           0                 5.0            17.0
#
#        order_time_of_day   distance  distance_bins  order_time_bins
# 0                morning   3.025149          short          morning
# 1                evening  20.183530      very long          evening
# 2                morning   1.552758          short          morning
# 3                evening   7.790401         medium          evening
# 4              afternoon   6.210138         medium        afternoon
# ...                  ...        ...            ...              ...
# 45497            morning   1.489846          short          morning
# 45498            evening        NaN            NaN          evening
# 45499              night   4.657195          short            night
# 45500          afternoon   6.232393         medium        afternoon
# 45501            evening  12.074396           long          evening
#
# [45502 rows x 28 columns]

# %%
df1=swiggy.copy().dropna()
df1
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 0        INDORES13DEL02   37.0      4.9            22.745049
# 1        BANGRES18DEL02   34.0      4.5            12.913041
# 2        BANGRES19DEL01   23.0      4.4            12.914264
# 3       COIMBRES13DEL02   38.0      4.7            11.003669
# 4        CHENRES12DEL01   32.0      4.6            12.972793
# ...                  ...   ...      ...                  ...
# 45496  RANCHIRES16DEL01   35.0      4.2            23.371292
# 45497     JAPRES04DEL01   30.0      4.8            26.902328
# 45499    CHENRES08DEL03   30.0      4.9            13.022394
# 45500   COIMBRES11DEL01   20.0      4.7            11.001753
# 45501  RANCHIRES09DEL02   23.0      4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 0                 75.892471          22.765049           75.912471
# 1                 77.683237          13.043041           77.813237
# 2                 77.678400          12.924264           77.688400
# 3                 76.976494          11.053669           77.026494
# 4                 80.249982          13.012793           80.289982
# ...                     ...                ...                 ...
# 45496             85.327872          23.481292           85.437872
# 45497             75.794257          26.912328           75.804257
# 45499             80.242439          13.052394           80.272439
# 45500             76.986241          11.041753           77.026241
# 45501             85.325731          23.431058           85.405731
#
#        order_date     weather traffic  ...  order_day order_month  \
# 0      2022-03-19       sunny    high  ...         19           3
# 1      2022-03-25      stormy     jam  ...         25           3
# 2      2022-03-19  sandstorms     low  ...         19           3
# 3      2022-04-05       sunny  medium  ...          5           4
# 4      2022-03-26      cloudy    high  ...         26           3
# ...           ...         ...     ...  ...        ...         ...
# 45496  2022-03-08       windy     jam  ...          8           3
# 45497  2022-03-24       windy    high  ...         24           3
# 45499  2022-03-11      cloudy     low  ...         11           3
# 45500  2022-03-07      cloudy    high  ...          7           3
# 45501  2022-03-02         fog  medium  ...          2           3
#
#       order_day_of_week  is_weekend pickup_time_minutes order_time_hour  \
# 0              saturday           1                15.0            11.0
# 1                friday           0                 5.0            19.0
# 2              saturday           1                15.0             8.0
# 3               tuesday           0                10.0            18.0
# 4              saturday           1                15.0            13.0
# ...                 ...         ...                 ...             ...
# 45496           tuesday           0                10.0            21.0
# 45497          thursday           0                10.0            11.0
# 45499            friday           0                15.0            23.0
# 45500            monday           0                 5.0            13.0
# 45501         wednesday           0                 5.0            17.0
#
#        order_time_of_day   distance  distance_bins  order_time_bins
# 0                morning   3.025149          short          morning
# 1                evening  20.183530      very long          evening
# 2                morning   1.552758          short          morning
# 3                evening   7.790401         medium          evening
# 4              afternoon   6.210138         medium        afternoon
# ...                  ...        ...            ...              ...
# 45496              night  16.600272           long            night
# 45497            morning   1.489846          short          morning
# 45499              night   4.657195          short            night
# 45500          afternoon   6.232393         medium        afternoon
# 45501            evening  12.074396           long          evening
#
# [38064 rows x 28 columns]

# %%
columns_to_drop=[
    'rider_id',
    'restaurant_latitude',
    'restaurant_longitude',	
    'delivery_latitude',
    'delivery_longitude',
    'order_date',
    'order_time_of_day',
    "order_time_hour",
    "order_day",
    "city_name",
    "order_day_of_week",
    "order_month"
]

# %%
df1.drop(columns=columns_to_drop,inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38064 entries, 0 to 45501
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  38064 non-null  float64
#  1   ratings              38064 non-null  float64
#  2   weather              38064 non-null  object
#  3   traffic              38064 non-null  object
#  4   vehicle_condition    38064 non-null  int64
#  5   type_of_order        38064 non-null  object
#  6   type_of_vehicle      38064 non-null  object
#  7   multiple_deliveries  38064 non-null  float64
#  8   festival             38064 non-null  object
#  9   city_type            38064 non-null  object
#  10  time_taken           38064 non-null  int64
#  11  is_weekend           38064 non-null  int64
#  12  pickup_time_minutes  38064 non-null  float64
#  13  distance             38064 non-null  float64
#  14  distance_bins        38064 non-null  category
#  15  order_time_bins      38064 non-null  category
# dtypes: category(2), float64(5), int64(3), object(6)
# memory usage: 4.4+ MB

# %%
df1.isnull().mean()
# Out:
# age                    0.0
# ratings                0.0
# weather                0.0
# traffic                0.0
# vehicle_condition      0.0
# type_of_order          0.0
# type_of_vehicle        0.0
# multiple_deliveries    0.0
# festival               0.0
# city_type              0.0
# time_taken             0.0
# is_weekend             0.0
# pickup_time_minutes    0.0
# distance               0.0
# distance_bins          0.0
# order_time_bins        0.0
# dtype: float64

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
X=df1.drop(columns=['time_taken'])
X
# Out:
#         age  ratings     weather traffic  vehicle_condition type_of_order  \
# 0      37.0      4.9       sunny    high                  2         snack
# 1      34.0      4.5      stormy     jam                  2         snack
# 2      23.0      4.4  sandstorms     low                  0        drinks
# 3      38.0      4.7       sunny  medium                  0        buffet
# 4      32.0      4.6      cloudy    high                  1         snack
# ...     ...      ...         ...     ...                ...           ...
# 45496  35.0      4.2       windy     jam                  2        drinks
# 45497  30.0      4.8       windy    high                  1          meal
# 45499  30.0      4.9      cloudy     low                  1        drinks
# 45500  20.0      4.7      cloudy    high                  0         snack
# 45501  23.0      4.9         fog  medium                  2         snack
#
#       type_of_vehicle  multiple_deliveries festival      city_type  \
# 0          motorcycle                  0.0       no          urban
# 1             scooter                  1.0       no  metropolitian
# 2          motorcycle                  1.0       no          urban
# 3          motorcycle                  1.0       no  metropolitian
# 4             scooter                  1.0       no  metropolitian
# ...               ...                  ...      ...            ...
# 45496      motorcycle                  1.0       no  metropolitian
# 45497      motorcycle                  0.0       no  metropolitian
# 45499         scooter                  0.0       no  metropolitian
# 45500      motorcycle                  1.0       no  metropolitian
# 45501         scooter                  1.0       no  metropolitian
#
#        is_weekend  pickup_time_minutes   distance distance_bins  \
# 0               1                 15.0   3.025149         short
# 1               0                  5.0  20.183530     very long
# 2               1                 15.0   1.552758         short
# 3               0                 10.0   7.790401        medium
# 4               1                 15.0   6.210138        medium
# ...           ...                  ...        ...           ...
# 45496           0                 10.0  16.600272          long
# 45497           0                 10.0   1.489846         short
# 45499           0                 15.0   4.657195         short
# 45500           0                  5.0   6.232393        medium
# 45501           0                  5.0  12.074396          long
#
#       order_time_bins
# 0             morning
# 1             evening
# 2             morning
# 3             evening
# 4           afternoon
# ...               ...
# 45496           night
# 45497         morning
# 45499           night
# 45500       afternoon
# 45501         evening
#
# [38064 rows x 15 columns]

# %%
Y=df1['time_taken']
Y
# Out:
# 0        24
# 1        33
# 2        26
# 3        21
# 4        30
#          ..
# 45496    33
# 45497    32
# 45499    16
# 45500    26
# 45501    36
# Name: time_taken, Length: 38064, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
print("The size of train data is",X_train.shape)
print("The shape of test data is",X_test.shape)
# Out:
# The size of train data is (30451, 15)
# The shape of test data is (7613, 15)

# %%
numerical_col=[cols for cols in df1.columns if df1[cols].dtype in ['int64','float64'] and cols !='time_taken']
numerical_col
# Out:
# ['age',
#  'ratings',
#  'vehicle_condition',
#  'multiple_deliveries',
#  'is_weekend',
#  'pickup_time_minutes',
#  'distance']

# %%
categorical_col=[cols for cols in df1.columns if df1[cols].dtype in ['object','category']]
categorical_col
# Out:
# ['weather',
#  'traffic',
#  'type_of_order',
#  'type_of_vehicle',
#  'festival',
#  'city_type',
#  'distance_bins',
#  'order_time_bins']

# %%
nominal_col=['weather','type_of_order','type_of_vehicle','festival','distance_bins','order_time_bins']
ordinal_col=['traffic','city_type']

# %%
len(numerical_col+nominal_col+ordinal_col)
# Out:
# 15

# %%
df1['traffic'].unique()
# Out:
# array(['high', 'jam', 'low', 'medium'], dtype=object)

# %%
df1['city_type'].unique()
# Out:
# array(['urban', 'metropolitian', 'semi-urban'], dtype=object)

# %%
traffic_groups=['low','medium','high','jam']
city_groups=['semi-urban','urban','metropolitian']

# %%
preprocessor=ColumnTransformer(
    [
        ("scaler",StandardScaler(),numerical_col),
        ("ohe",OneHotEncoder(drop="first",sparse_output=False,handle_unknown="ignore"),nominal_col),
        ("ordinal",OrdinalEncoder(categories=[traffic_groups,city_groups]),ordinal_col)
    ],remainder='passthrough'
)
preprocessor.set_output(transform="pandas")
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('scaler', StandardScaler(),
#                                  ['age', 'ratings', 'vehicle_condition',
#                                   'multiple_deliveries', 'is_weekend',
#                                   'pickup_time_minutes', 'distance']),
#                                 ('ohe',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore',
#                                                sparse_output=False),
#                                  ['weather', 'type_of_order', 'type_of_vehicle',
#                                   'festival', 'distance_bins',
#                                   'order_time_bins']),
#                                 ('ordinal',
#                                  OrdinalEncoder(categories=[['low', 'medium',
#                                                              'high', 'jam'],
#                                                             ['semi-urban',
#                                                              'urban',
#                                                              'metropolitian']]),
#                                  ['traffic', 'city_type'])])

# %%
base_model=RandomForestRegressor()

# %%
pipeline=Pipeline([
    ("preprocessor",preprocessor),
    ("base_model",base_model)
])

# %%
pipeline.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('scaler', StandardScaler(),
#                                                   ['age', 'ratings',
#                                                    'vehicle_condition',
#                                                    'multiple_deliveries',
#                                                    'is_weekend',
#                                                    'pickup_time_minutes',
#                                                    'distance']),
#                                                  ('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['weather', 'type_of_order',
#                                                    'type_of_vehicle',
#                                                    'festival', 'distance_bins',
#                                                    'order_time_bins']),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(categories=[['low',
#                                                                               'medium',
#                                                                               'high',
#                                                                               'jam'],
#                                                                              ['semi-urban',
#                                                                               'urban',
#                                                                               'metropolitian']]),
#                                                   ['traffic', 'city_type'])])),
#                 ('base_model', RandomForestRegressor())])

# %%
y_pred_test=pipeline.predict(X_test)
y_pred_train=pipeline.predict(X_train)

# %%
print(f"The train mean absolute error is:{round(mean_absolute_error(Y_train,y_pred_train),2)} min")
print(f"The test mean absolute error is:{round(mean_absolute_error(Y_test,y_pred_test),2)} min")
# Out:
# The train mean absolute error is:1.14 min
# The test mean absolute error is:3.14 min

# %%
print(f"The train r2 score is:{round(r2_score(Y_train,y_pred_train),2)}")
print(f"The test r2 score is:{round(r2_score(Y_test,y_pred_test),2)}")
# Out:
# The train r2 score is:0.98
# The test r2 score is:0.82

# %% [markdown]
# #### Imputing the missing values:

# %%
df2=swiggy.copy()
df2
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 0        INDORES13DEL02   37.0      4.9            22.745049
# 1        BANGRES18DEL02   34.0      4.5            12.913041
# 2        BANGRES19DEL01   23.0      4.4            12.914264
# 3       COIMBRES13DEL02   38.0      4.7            11.003669
# 4        CHENRES12DEL01   32.0      4.6            12.972793
# ...                  ...   ...      ...                  ...
# 45497     JAPRES04DEL01   30.0      4.8            26.902328
# 45498     AGRRES16DEL01   21.0      4.6                  NaN
# 45499    CHENRES08DEL03   30.0      4.9            13.022394
# 45500   COIMBRES11DEL01   20.0      4.7            11.001753
# 45501  RANCHIRES09DEL02   23.0      4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 0                 75.892471          22.765049           75.912471
# 1                 77.683237          13.043041           77.813237
# 2                 77.678400          12.924264           77.688400
# 3                 76.976494          11.053669           77.026494
# 4                 80.249982          13.012793           80.289982
# ...                     ...                ...                 ...
# 45497             75.794257          26.912328           75.804257
# 45498                   NaN                NaN                 NaN
# 45499             80.242439          13.052394           80.272439
# 45500             76.986241          11.041753           77.026241
# 45501             85.325731          23.431058           85.405731
#
#        order_date     weather traffic  ...  order_day order_month  \
# 0      2022-03-19       sunny    high  ...         19           3
# 1      2022-03-25      stormy     jam  ...         25           3
# 2      2022-03-19  sandstorms     low  ...         19           3
# 3      2022-04-05       sunny  medium  ...          5           4
# 4      2022-03-26      cloudy    high  ...         26           3
# ...           ...         ...     ...  ...        ...         ...
# 45497  2022-03-24       windy    high  ...         24           3
# 45498  2022-02-16       windy     jam  ...         16           2
# 45499  2022-03-11      cloudy     low  ...         11           3
# 45500  2022-03-07      cloudy    high  ...          7           3
# 45501  2022-03-02         fog  medium  ...          2           3
#
#       order_day_of_week  is_weekend pickup_time_minutes order_time_hour  \
# 0              saturday           1                15.0            11.0
# 1                friday           0                 5.0            19.0
# 2              saturday           1                15.0             8.0
# 3               tuesday           0                10.0            18.0
# 4              saturday           1                15.0            13.0
# ...                 ...         ...                 ...             ...
# 45497          thursday           0                10.0            11.0
# 45498         wednesday           0                15.0            19.0
# 45499            friday           0                15.0            23.0
# 45500            monday           0                 5.0            13.0
# 45501         wednesday           0                 5.0            17.0
#
#        order_time_of_day   distance  distance_bins  order_time_bins
# 0                morning   3.025149          short          morning
# 1                evening  20.183530      very long          evening
# 2                morning   1.552758          short          morning
# 3                evening   7.790401         medium          evening
# 4              afternoon   6.210138         medium        afternoon
# ...                  ...        ...            ...              ...
# 45497            morning   1.489846          short          morning
# 45498            evening        NaN            NaN          evening
# 45499              night   4.657195          short            night
# 45500          afternoon   6.232393         medium        afternoon
# 45501            evening  12.074396           long          evening
#
# [45502 rows x 28 columns]

# %%
df2.drop(columns=columns_to_drop,inplace=True)

# %%
X=df2.drop(columns=['time_taken'])
X
# Out:
#         age  ratings     weather traffic  vehicle_condition type_of_order  \
# 0      37.0      4.9       sunny    high                  2         snack
# 1      34.0      4.5      stormy     jam                  2         snack
# 2      23.0      4.4  sandstorms     low                  0        drinks
# 3      38.0      4.7       sunny  medium                  0        buffet
# 4      32.0      4.6      cloudy    high                  1         snack
# ...     ...      ...         ...     ...                ...           ...
# 45497  30.0      4.8       windy    high                  1          meal
# 45498  21.0      4.6       windy     jam                  0        buffet
# 45499  30.0      4.9      cloudy     low                  1        drinks
# 45500  20.0      4.7      cloudy    high                  0         snack
# 45501  23.0      4.9         fog  medium                  2         snack
#
#       type_of_vehicle  multiple_deliveries festival      city_type  \
# 0          motorcycle                  0.0       no          urban
# 1             scooter                  1.0       no  metropolitian
# 2          motorcycle                  1.0       no          urban
# 3          motorcycle                  1.0       no  metropolitian
# 4             scooter                  1.0       no  metropolitian
# ...               ...                  ...      ...            ...
# 45497      motorcycle                  0.0       no  metropolitian
# 45498      motorcycle                  1.0       no  metropolitian
# 45499         scooter                  0.0       no  metropolitian
# 45500      motorcycle                  1.0       no  metropolitian
# 45501         scooter                  1.0       no  metropolitian
#
#        is_weekend  pickup_time_minutes   distance distance_bins  \
# 0               1                 15.0   3.025149         short
# 1               0                  5.0  20.183530     very long
# 2               1                 15.0   1.552758         short
# 3               0                 10.0   7.790401        medium
# 4               1                 15.0   6.210138        medium
# ...           ...                  ...        ...           ...
# 45497           0                 10.0   1.489846         short
# 45498           0                 15.0        NaN           NaN
# 45499           0                 15.0   4.657195         short
# 45500           0                  5.0   6.232393        medium
# 45501           0                  5.0  12.074396          long
#
#       order_time_bins
# 0             morning
# 1             evening
# 2             morning
# 3             evening
# 4           afternoon
# ...               ...
# 45497         morning
# 45498         evening
# 45499           night
# 45500       afternoon
# 45501         evening
#
# [45502 rows x 15 columns]

# %%
Y=df2['time_taken']
Y
# Out:
# 0        24
# 1        33
# 2        26
# 3        21
# 4        30
#          ..
# 45497    32
# 45498    36
# 45499    16
# 45500    26
# 45501    36
# Name: time_taken, Length: 45502, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
print("The shape of training dataset is:",X_train.shape)
print("The shape of testing dataset is:",X_test.shape)
# Out:
# The shape of training dataset is: (36401, 15)
# The shape of testing dataset is: (9101, 15)

# %%
pt=PowerTransformer()

# %%
Y_train_pt=pt.fit_transform(Y_train.values.reshape(-1,1))
Y_test_pt=pt.transform(Y_test.values.reshape(-1,1))

# %%
X_train.isnull().mean()*100
# Out:
# age                    4.027362
# ratings                4.150985
# weather                1.170298
# traffic                1.140079
# vehicle_condition      0.000000
# type_of_order          0.000000
# type_of_vehicle        0.000000
# multiple_deliveries    2.236202
# festival               0.480756
# city_type              2.596083
# is_weekend             0.000000
# pickup_time_minutes    3.579572
# distance               7.878904
# distance_bins          7.878904
# order_time_bins        3.579572
# dtype: float64

# %%
X_train['age'].describe()
# Out:
# count    34935.000000
# mean        29.583598
# std          5.763287
# min         20.000000
# 25%         25.000000
# 50%         30.000000
# 75%         35.000000
# max         39.000000
# Name: age, dtype: float64

# %%
test_stats,p_value=stats.jarque_bera(X_train['age'].dropna())
p_value
# Out:
# np.float64(0.0)

# %%
sns.kdeplot(X_train['age'],label="Before Imputation")
sns.kdeplot(X_train['age'].fillna(X_train['age'].median()),label="After imputation")

plt.legend()
plt.show()

# %% [markdown]
# Age is not normally distributed and has <5% missing data. So, here we try to impute it using median, however, we can see that there is a peak around 30 years which is the medain value that was used to impute the missing values. Thus, the distribution hasnot been preserved.

# %%
X_train['ratings'].describe()
# Out:
# count    34890.000000
# mean         4.633411
# std          0.316294
# min          2.500000
# 25%          4.500000
# 50%          4.700000
# 75%          4.900000
# max          5.000000
# Name: ratings, dtype: float64

# %%
test_stats,p_value=stats.jarque_bera(X_train['ratings'].dropna())
p_value
# Out:
# np.float64(0.0)

# %%
sns.kdeplot(X_train['ratings'],label="Before Imputation")
sns.kdeplot(X_train['ratings'].fillna(X_train['ratings'].median()),label="After imputation")

plt.legend()
plt.show()

# %% [markdown]
# Rating is not normally distributed and has <5% missing data. So, here we try to impute it using median. Though there is a slight peak in the median value, much of the distribution is preserved.

# %%
X_train['weather'].value_counts()
# Out:
# weather
# fog           6141
# stormy        6125
# sandstorms    6005
# cloudy        5941
# windy         5912
# sunny         5851
# Name: count, dtype: int64

# %% [markdown]
# No dominant category here. So, we will not fill it with the mode.

# %%
X_train['traffic'].value_counts()
# Out:
# traffic
# low       12365
# jam       11329
# medium     8768
# high       3524
# Name: count, dtype: int64

# %% [markdown]
# No dominant category here. So, we will not fill it with the mode.

# %%
X_train['multiple_deliveries'].value_counts()
# Out:
# multiple_deliveries
# 1.0    22557
# 0.0    11141
# 2.0     1611
# 3.0      278
# Name: count, dtype: int64

# %% [markdown]
# 1 is the dominant category, so we can fill it with the mode.

# %%
X_train['festival'].value_counts()
# Out:
# festival
# no     35492
# yes      734
# Name: count, dtype: int64

# %% [markdown]
# "No" is the dominant category, so we can fill it with the mode.

# %%
X_train['city_type'].value_counts()
# Out:
# city_type
# metropolitian    27267
# urban             8055
# semi-urban         134
# Name: count, dtype: int64

# %% [markdown]
# "metropolitian" is the dominant category, so we can fill it with the mode.

# %%
X_train['pickup_time_minutes'].describe()
# Out:
# count    35098.000000
# mean         9.995441
# std          4.094154
# min          5.000000
# 25%          5.000000
# 50%         10.000000
# 75%         15.000000
# max         15.000000
# Name: pickup_time_minutes, dtype: float64

# %%
test_stats,p_value=stats.jarque_bera(X_train['pickup_time_minutes'].dropna())
p_value
# Out:
# np.float64(0.0)

# %%
sns.kdeplot(X_train['pickup_time_minutes'],label="Before Imputation")
sns.kdeplot(X_train['pickup_time_minutes'].fillna(X_train['pickup_time_minutes'].median()),label="After imputation")

plt.legend()
plt.show()

# %% [markdown]
# Here, we can see that the multimodel pattern largely remains preserved after the imputation.

# %%
X_train['distance'].describe()
# Out:
# count    33533.000000
# mean         9.741460
# std          5.605947
# min          1.465067
# 25%          4.657673
# 50%          9.219124
# 75%         13.681416
# max         20.969489
# Name: distance, dtype: float64

# %%
test_stats,p_value=stats.jarque_bera(X_train['distance'].dropna())
p_value
# Out:
# np.float64(0.0)

# %%
sns.kdeplot(X_train['distance'],label="Before Imputation")
sns.kdeplot(X_train['distance'].fillna(X_train['distance'].median()),label="After imputation")

plt.legend()
plt.show()

# %% [markdown]
# There is a peak in the median value after the imputation. so the distribution is not preserved.

# %%
X_train['distance_bins'].value_counts()
# Out:
# distance_bins
# medium       12104
# short         9398
# long          8577
# very long     3454
# Name: count, dtype: int64

# %%
X_train['order_time_bins'].value_counts()
# Out:
# order_time_bins
# night             14683
# evening           10678
# morning            6169
# afternoon          3217
# after_midnight      351
# Name: count, dtype: int64

# %% [markdown]
# There is no obvious dominant category in both of the features.

# %%
imputing_mode=['multiple_deliveries','festival','city_type']
imputing_median=['ratings','pickup_time_minutes']
imputing_missing_indicator=[col for col in nominal_col if df2[col].dtypes in ['object','category'] and col not in imputing_mode]
imputing_missing_indicator
# Out:
# ['weather',
#  'type_of_order',
#  'type_of_vehicle',
#  'distance_bins',
#  'order_time_bins']

# %%
simple_imputer=ColumnTransformer(
    [
        ("mode",SimpleImputer(strategy="most_frequent"),imputing_mode),
        ("missing_indicator",SimpleImputer(strategy="constant",fill_value="missing"),imputing_missing_indicator),
        ("median",SimpleImputer(strategy="median"),imputing_median)
    ],remainder="passthrough",n_jobs=-1,force_int_remainder_cols=False,verbose_feature_names_out=False
)
simple_imputer
# Out:
# ColumnTransformer(force_int_remainder_cols=False, n_jobs=-1,
#                   remainder='passthrough',
#                   transformers=[('mode',
#                                  SimpleImputer(strategy='most_frequent'),
#                                  ['multiple_deliveries', 'festival',
#                                   'city_type']),
#                                 ('missing_indicator',
#                                  SimpleImputer(fill_value='missing',
#                                                strategy='constant'),
#                                  ['weather', 'type_of_order', 'type_of_vehicle',
#                                   'distance_bins', 'order_time_bins']),
#                                 ('median', SimpleImputer(strategy='median'),
#                                  ['ratings', 'pickup_time_minutes'])],
#                   verbose_feature_names_out=False)

# %%
simple_imputer.fit_transform(X_train)
# Out:
#       multiple_deliveries festival      city_type     weather type_of_order  \
# 1901                  1.0       no  metropolitian      stormy          meal
# 32233                 0.0       no          urban  sandstorms        buffet
# 41301                 2.0       no  metropolitian      stormy        buffet
# 8362                  1.0       no          urban      cloudy        buffet
# 40881                 1.0       no          urban       windy          meal
# ...                   ...      ...            ...         ...           ...
# 40059                 1.0       no  metropolitian      stormy        buffet
# 28017                 1.0       no          urban      stormy        drinks
# 29199                 1.0       no  metropolitian       windy        buffet
# 40061                 0.0       no  metropolitian  sandstorms          meal
# 17673                 1.0       no  metropolitian      cloudy        drinks
#
#         type_of_vehicle distance_bins order_time_bins  ratings  \
# 1901   electric_scooter       missing         evening      4.6
# 32233        motorcycle        medium         evening      4.8
# 41301        motorcycle          long         evening      4.4
# 8362            scooter          long         evening      4.0
# 40881  electric_scooter         short         morning      4.7
# ...                 ...           ...             ...      ...
# 40059  electric_scooter     very long           night      4.7
# 28017        motorcycle         short         morning      4.8
# 29199        motorcycle     very long         evening      4.7
# 40061        motorcycle        medium           night      4.4
# 17673           scooter         short         morning      4.6
#
#        pickup_time_minutes   age traffic  vehicle_condition  is_weekend  \
# 1901                   5.0  21.0  medium                  2           0
# 32233                  5.0  27.0  medium                  1           1
# 41301                  5.0  31.0  medium                  0           0
# 8362                   5.0  35.0  medium                  2           0
# 40881                 10.0  20.0     low                  2           1
# ...                    ...   ...     ...                ...         ...
# 40059                  5.0  26.0     jam                  2           0
# 28017                 10.0  27.0     low                  1           0
# 29199                 15.0  32.0  medium                  0           0
# 40061                 10.0  37.0     low                  0           0
# 17673                 10.0  35.0    high                  2           1
#
#         distance
# 1901         NaN
# 32233  10.867138
# 41301  12.162012
# 8362   13.631344
# 40881   3.073772
# ...          ...
# 40059  20.831034
# 28017   1.536850
# 29199  20.852271
# 40061   7.790159
# 17673   3.104827
#
# [36401 rows x 15 columns]

# %%
simple_imputer.fit_transform(X_train).isna().mean()*100
# Out:
# multiple_deliveries    0.000000
# festival               0.000000
# city_type              0.000000
# weather                0.000000
# type_of_order          0.000000
# type_of_vehicle        0.000000
# distance_bins          0.000000
# order_time_bins        0.000000
# ratings                0.000000
# pickup_time_minutes    0.000000
# age                    4.027362
# traffic                1.140079
# vehicle_condition      0.000000
# is_weekend             0.000000
# distance               7.878904
# dtype: float64

# %%
numerical_col
# Out:
# ['age',
#  'ratings',
#  'vehicle_condition',
#  'multiple_deliveries',
#  'is_weekend',
#  'pickup_time_minutes',
#  'distance']

# %%
preprocessor=ColumnTransformer(
    [
        ("scaler",StandardScaler(),numerical_col),
        ("ohe",OneHotEncoder(drop="first",sparse_output=False,handle_unknown="ignore"),nominal_col),
        ("ordinal",OrdinalEncoder(categories=[traffic_groups,city_groups],encoded_missing_value=-999,handle_unknown="use_encoded_value",unknown_value=-1),ordinal_col)
    ],remainder='passthrough'
)

# %%
preprocessor.fit_transform(X_train)
# Out:
#        scaler__age  scaler__ratings  scaler__vehicle_condition  \
# 1901     -1.489379        -0.105633                   1.172137
# 32233    -0.448292         0.526699                  -0.024961
# 41301     0.245766        -0.737965                  -1.222059
# 8362      0.939825        -2.002629                   1.172137
# 40881    -1.662894         0.210533                   1.172137
# ...            ...              ...                        ...
# 40059    -0.621806         0.210533                   1.172137
# 28017    -0.448292         0.526699                  -0.024961
# 29199     0.419281         0.210533                  -1.222059
# 40061     1.286854        -0.737965                  -1.222059
# 17673     0.939825        -0.105633                   1.172137
#
#        scaler__multiple_deliveries  scaler__is_weekend  \
# 1901                      0.441664           -0.614852
# 32233                    -1.309785            1.626408
# 41301                     2.193114           -0.614852
# 8362                      0.441664           -0.614852
# 40881                     0.441664            1.626408
# ...                            ...                 ...
# 40059                     0.441664           -0.614852
# 28017                     0.441664           -0.614852
# 29199                     0.441664           -0.614852
# 40061                    -1.309785           -0.614852
# 17673                     0.441664            1.626408
#
#        scaler__pickup_time_minutes  scaler__distance  ohe__weather_fog  \
# 1901                     -1.220157               NaN               0.0
# 32233                    -1.220157          0.200804               0.0
# 41301                    -1.220157          0.431789               0.0
# 8362                     -1.220157          0.693896               0.0
# 40881                     0.001113         -1.189413               0.0
# ...                            ...               ...               ...
# 40059                    -1.220157          1.978210               0.0
# 28017                     0.001113         -1.463576               0.0
# 29199                     1.222384          1.981998               0.0
# 40061                     0.001113         -0.348082               0.0
# 17673                     0.001113         -1.183873               0.0
#
#        ohe__weather_sandstorms  ohe__weather_stormy  ...  \
# 1901                       0.0                  1.0  ...
# 32233                      1.0                  0.0  ...
# 41301                      0.0                  1.0  ...
# 8362                       0.0                  0.0  ...
# 40881                      0.0                  0.0  ...
# ...                        ...                  ...  ...
# 40059                      0.0                  1.0  ...
# 28017                      0.0                  1.0  ...
# 29199                      0.0                  0.0  ...
# 40061                      1.0                  0.0  ...
# 17673                      0.0                  0.0  ...
#
#        ohe__distance_bins_short  ohe__distance_bins_very long  \
# 1901                        0.0                           0.0
# 32233                       0.0                           0.0
# 41301                       0.0                           0.0
# 8362                        0.0                           0.0
# 40881                       1.0                           0.0
# ...                         ...                           ...
# 40059                       0.0                           1.0
# 28017                       1.0                           0.0
# 29199                       0.0                           1.0
# 40061                       0.0                           0.0
# 17673                       1.0                           0.0
#
#        ohe__distance_bins_nan  ohe__order_time_bins_afternoon  \
# 1901                      1.0                             0.0
# 32233                     0.0                             0.0
# 41301                     0.0                             0.0
# 8362                      0.0                             0.0
# 40881                     0.0                             0.0
# ...                       ...                             ...
# 40059                     0.0                             0.0
# 28017                     0.0                             0.0
# 29199                     0.0                             0.0
# 40061                     0.0                             0.0
# 17673                     0.0                             0.0
#
#        ohe__order_time_bins_evening  ohe__order_time_bins_morning  \
# 1901                            1.0                           0.0
# 32233                           1.0                           0.0
# 41301                           1.0                           0.0
# 8362                            1.0                           0.0
# 40881                           0.0                           1.0
# ...                             ...                           ...
# 40059                           0.0                           0.0
# 28017                           0.0                           1.0
# 29199                           1.0                           0.0
# 40061                           0.0                           0.0
# 17673                           0.0                           1.0
#
#        ohe__order_time_bins_night  ohe__order_time_bins_nan  ordinal__traffic  \
# 1901                          0.0                       0.0               1.0
# 32233                         0.0                       0.0               1.0
# 41301                         0.0                       0.0               1.0
# 8362                          0.0                       0.0               1.0
# 40881                         0.0                       0.0               0.0
# ...                           ...                       ...               ...
# 40059                         1.0                       0.0               3.0
# 28017                         0.0                       0.0               0.0
# 29199                         0.0                       0.0               1.0
# 40061                         1.0                       0.0               0.0
# 17673                         0.0                       0.0               2.0
#
#        ordinal__city_type
# 1901                  2.0
# 32233                 1.0
# 41301                 2.0
# 8362                  1.0
# 40881                 1.0
# ...                   ...
# 40059                 2.0
# 28017                 1.0
# 29199                 2.0
# 40061                 2.0
# 17673                 2.0
#
# [36401 rows x 32 columns]

# %%
preprocessor.fit_transform(X_train).isna().sum().loc[lambda ser : ser.ge(1)]
# Out:
# scaler__age                    1466
# scaler__ratings                1511
# scaler__multiple_deliveries     814
# scaler__pickup_time_minutes    1303
# scaler__distance               2868
# dtype: int64

# %%
knn_imputer=KNNImputer(n_neighbors=5)

# %%
preprocessing_pipeline=Pipeline(steps=[
    ("simple_imputer",simple_imputer),
    ("preprocessor",preprocessor),
    ("knn_imputer",knn_imputer)
])

# %%
model_pipeline=Pipeline(steps=[
    ("preprocessing_pipeline",preprocessing_pipeline),
    ("base_model",base_model)
])
model_pipeline
# Out:
# Pipeline(steps=[('preprocessing_pipeline',
#                  Pipeline(steps=[('simple_imputer',
#                                   ColumnTransformer(force_int_remainder_cols=False,
#                                                     n_jobs=-1,
#                                                     remainder='passthrough',
#                                                     transformers=[('mode',
#                                                                    SimpleImputer(strategy='most_frequent'),
#                                                                    ['multiple_deliveries',
#                                                                     'festival',
#                                                                     'city_type']),
#                                                                   ('missing_indicator',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant'),
#                                                                    ['we...
#                                                                     'type_of_vehicle',
#                                                                     'festival',
#                                                                     'distance_bins',
#                                                                     'order_time_bins']),
#                                                                   ('ordinal',
#                                                                    OrdinalEncoder(categories=[['low',
#                                                                                                'medium',
#                                                                                                'high',
#                                                                                                'jam'],
#                                                                                               ['semi-urban',
#                                                                                                'urban',
#                                                                                                'metropolitian']],
#                                                                                   encoded_missing_value=-999,
#                                                                                   handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1),
#                                                                    ['traffic',
#                                                                     'city_type'])])),
#                                  ('knn_imputer', KNNImputer())])),
#                 ('base_model', RandomForestRegressor())])

# %%
model_pipeline.fit(X_train,Y_train_pt.values.ravel())
# Out:
# Pipeline(steps=[('preprocessing_pipeline',
#                  Pipeline(steps=[('simple_imputer',
#                                   ColumnTransformer(force_int_remainder_cols=False,
#                                                     n_jobs=-1,
#                                                     remainder='passthrough',
#                                                     transformers=[('mode',
#                                                                    SimpleImputer(strategy='most_frequent'),
#                                                                    ['multiple_deliveries',
#                                                                     'festival',
#                                                                     'city_type']),
#                                                                   ('missing_indicator',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant'),
#                                                                    ['we...
#                                                                     'type_of_vehicle',
#                                                                     'festival',
#                                                                     'distance_bins',
#                                                                     'order_time_bins']),
#                                                                   ('ordinal',
#                                                                    OrdinalEncoder(categories=[['low',
#                                                                                                'medium',
#                                                                                                'high',
#                                                                                                'jam'],
#                                                                                               ['semi-urban',
#                                                                                                'urban',
#                                                                                                'metropolitian']],
#                                                                                   encoded_missing_value=-999,
#                                                                                   handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1),
#                                                                    ['traffic',
#                                                                     'city_type'])])),
#                                  ('knn_imputer', KNNImputer())])),
#                 ('base_model', RandomForestRegressor())])

# %%
y_pred_train=model_pipeline.predict(X_train)
y_pred_test=model_pipeline.predict(X_test)

# %%
y_pred_train_org = pt.inverse_transform(y_pred_train.reshape(-1,1))
y_pred_test_org = pt.inverse_transform(y_pred_test.reshape(-1,1))

# %%
print(f"The train error is {mean_absolute_error(Y_train,y_pred_train_org):.2f} minutes")
print(f"The test error is {mean_absolute_error(Y_test,y_pred_test_org):.2f} minutes")
# Out:
# The train error is 1.22 minutes
# The test error is 3.28 minutes

# %%
print(f"The train r2 score is {r2_score(Y_train,y_pred_train_org):.2f}")
print(f"The test r2 score is {r2_score(Y_test,y_pred_test_org):.2f}")
# Out:
# The train r2 score is 0.97
# The test r2 score is 0.80

# %%
scores = cross_val_score(model_pipeline,X_train,Y_train_pt.values.ravel(),cv=5,scoring="r2",n_jobs=-1)
scores
# Out:
# array([0.77935687, 0.78051006, 0.78508896, 0.78535166, 0.77369277])

# %%
scores.mean()
# Out:
# np.float64(0.7808000664917201)
